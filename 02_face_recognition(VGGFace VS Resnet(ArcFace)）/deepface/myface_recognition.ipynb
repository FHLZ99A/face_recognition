# %%
from deepface import DeepFace
import matplotlib.pyplot as plt

# %%
my_face = "pictures/me_01.jpg"

# %%
img = DeepFace.detectFace(my_face)

# %%
plt.imshow(img)

# %%
model_name = 'ArcFace'

# %%
a = DeepFace.stream(db_path='image/',model_name=model_name)
# Out:
# Detector backend is  opencv
# ArcFace  is built
# Emotion model loaded
# Age model loaded
# Gender model loaded
# Facial attibute analysis models loaded in  1.638556718826294  seconds
# ...
# Finding embedding for me.jpg: 100%|██████████████████████████████████████████████████████| 3/3 [00:03<00:00,  1.29s/it]
# Embeddings found for given data set in  3.8758857250213623  seconds

# %%
print(a)
