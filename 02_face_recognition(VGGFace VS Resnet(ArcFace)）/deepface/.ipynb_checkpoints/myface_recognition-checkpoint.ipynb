# %%
from deepface import DeepFace
import matplotlib.pyplot as plt

# %%
my_face = "pictures/me.jpg"

# %%
img = DeepFace.detectFace(my_face)

# %%
plt.imshow(img)

# %%
model_name = 'VGG-Face'

# %%
a = DeepFace.stream(db_path='image/',model_name=model_name)
# Out:
# Detector backend is  opencv
# VGG-Face  is built
# Emotion model loaded
# Age model loaded
# Gender model loaded
# Facial attibute analysis models loaded in  0.0029921531677246094  seconds
# Finding embedding for img2.jpg:   0%|                                                            | 0/3 [00:00<?, ?it/s]
# 1/1 [==============================] - 1s 824ms/step
# Finding embedding for img3.jpg:  33%|█████████████████▎                                  | 1/3 [00:01<00:02,  1.14s/it]
# 1/1 [==============================] - 0s 14ms/step
# Finding embedding for me.jpg:  67%|████████████████████████████████████                  | 2/3 [00:01<00:00,  1.17it/s]
# 1/1 [==============================] - 0s 14ms/step
# Finding embedding for me.jpg: 100%|██████████████████████████████████████████████████████| 3/3 [00:01<00:00,  1.55it/s]
# Embeddings found for given data set in  1.9468357563018799  seconds

# %%
print(a)
